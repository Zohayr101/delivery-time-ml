# %% [markdown]
# # Week 1 - Problem Definition & Dataset Setup

# %%
import pandas as pd

df = pd.read_csv('../data/raw/semi_truck_delivery_data.csv')

print(df.head())

print(df.info())

print(df.describe())
